# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Data file.csv")
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %%
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 0    220.13    260.13                2.0                0.0              1539
# 1   3691.26   3691.26               20.0                0.0              5787
# 2    900.13    900.13                3.0                0.0              1539
# 3    159.42    159.42               41.0                0.0               947
# 4   1098.90   1098.90                4.0                0.0              2309
#
#    cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0              2          21.0             3078.0                1539.0
# 1              1           0.0             5787.0                5787.0
# 2              1           0.0             1539.0                1539.0
# 3              0           0.0                0.0                   0.0
# 4              7           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90 pcircle       pdate
# 0                 0.0  29.000000  29.000000     UPW  2016-07-20
# 1                 0.0   0.000000   0.000000     UPW  2016-08-10
# 2                 0.0   0.000000   0.000000     UPW  2016-08-19
# 3                 0.0   0.000000   0.000000     UPW  2016-06-06
# 4                 0.0   2.333333   2.333333     UPW  2016-06-22

# %%
df.tail()
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# 209588   1089.19   1089.19                1.0                0.0
# 209589   1728.36   1728.36                4.0                0.0
# 209590   5861.83   8893.20                3.0                0.0
# 209591    411.83    984.58                2.0               38.0
# 209592    483.92    631.20               13.0                0.0
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# 209588              4048              3           2.0            10404.0
# 209589               773              4           1.0             3092.0
# 209590              1539              5           8.0             9334.0
# 209591               773              5           4.0            12154.0
# 209592              7526              2           1.0             9065.0
#
#         medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  \
# 209588                3178.0                 91.81              3
# 209589                 773.0                161.30              6
# 209590                1539.0                 51.13             11
# 209591                 773.0                164.00              6
# 209592                4532.5                356.70              3
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 209588             2              10404                3178.0
# 209589             2               4038                 773.0
# 209590             5              18592                1539.0
# 209591             4              17941                2410.5
# 209592            19              16591                7526.0
#
#         medianmarechprebal90  cnt_da_rech30  fr_da_rech30  cnt_da_rech90  \
# 209588                 91.81            0.0           0.0              0
# 209589                111.80            0.0           0.0              0
# 209590                 47.13            0.0           0.0              0
# 209591                100.00            0.0           0.0              1
# 209592                392.20            0.0           0.0              0
#
#         fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 209588             0            2            12              6.0
# 209589             0            3            18              6.0
# 209590             0            4            42             12.0
# 209591             0            2            18             12.0
# 209592             0            2            18             12.0
#
#         medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 209588                 0.0          2.0            12                6
# 209589                 0.0          3.0            18                6
# 209590                 0.0          6.0            54               12
# 209591                 0.0          3.0            24               12
# 209592                 0.0          2.0            18               12
#
#         medianamnt_loans90  payback30  payback90 pcircle       pdate
# 209588                 0.0        1.0   1.000000     UPW  2016-06-17
# 209589                 0.0        1.0   1.000000     UPW  2016-06-12
# 209590                 0.0        4.0   3.833333     UPW  2016-07-29
# 209591                 0.0        0.0  10.500000     UPW  2016-07-25
# 209592                 0.0        0.0   0.000000     UPW  2016-07-07

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
df.shape
# Out:
# (209593, 37)

# %% [markdown]
# # Observation

# %% [markdown]
# this dataset has 1000rows and 40 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
#  14  medianamnt_ma_rech30  209593 non-null  float64
#  15  medianmarechprebal30  209593 non-null  float64
#  16  cnt_ma_rech90         209593 non-null  int64
#  17  fr_ma_rech90          209593 non-null  int64
#  18  sumamnt_ma_rech90     209593 non-null  int64
#  19  medianamnt_ma_rech90  209593 non-null  float64
#  20  medianmarechprebal90  209593 non-null  float64
#  21  cnt_da_rech30         209593 non-null  float64
#  22  fr_da_rech30          209593 non-null  float64
#  23  cnt_da_rech90         209593 non-null  int64
#  24  fr_da_rech90          209593 non-null  int64
#  25  cnt_loans30           209593 non-null  int64
#  26  amnt_loans30          209593 non-null  int64
#  27  maxamnt_loans30       209593 non-null  float64
#  28  medianamnt_loans30    209593 non-null  float64
#  29  cnt_loans90           209593 non-null  float64
#  30  amnt_loans90          209593 non-null  int64
#  31  maxamnt_loans90       209593 non-null  int64
#  32  medianamnt_loans90    209593 non-null  float64
#  33  payback30             209593 non-null  float64
#  34  payback90             209593 non-null  float64
#  35  pcircle               209593 non-null  object
#  36  pdate                 209593 non-null  object
# dtypes: float64(21), int64(13), object(3)
# memory usage: 59.2+ MB

# %% [markdown]
# # Observation

# %% [markdown]
# We have integer,float,and object data in dataset

# %%
df.describe()
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755168  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean     6082.515068    2692.581910    3483.406534        3755.847800
# std     10918.812767    4308.586781    5770.461279       53905.892230
# min       -93.012667  -23737.140000  -24720.580000         -29.000000
# 25%        42.692000     280.420000     300.260000           1.000000
# 50%      1500.000000    1083.570000    1334.000000           3.000000
# 75%      7802.790000    3356.940000    4201.790000           7.000000
# max    320630.000000  198926.110000  200148.110000      998650.377733
#
#        last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30   fr_ma_rech30  \
# count      209593.000000     209593.000000  209593.000000  209593.000000
# mean         3712.202921       2064.452797       3.978057    3737.355121
# std         53374.833430       2370.786034       4.256090   53643.625172
# min           -29.000000          0.000000       0.000000       0.000000
# 25%             0.000000        770.000000       1.000000       0.000000
# 50%             0.000000       1539.000000       3.000000       2.000000
# 75%             0.000000       2309.000000       5.000000       6.000000
# max        999171.809410      55000.000000     203.000000  999606.368132
#
#        sumamnt_ma_rech30  medianamnt_ma_rech30  medianmarechprebal30  \
# count      209593.000000         209593.000000         209593.000000
# mean         7704.501157           1812.817952           3851.927942
# std         10139.621714           2070.864620          54006.374433
# min             0.000000              0.000000           -200.000000
# 25%          1540.000000            770.000000             11.000000
# 50%          4628.000000           1539.000000             33.900000
# 75%         10010.000000           1924.000000             83.000000
# max        810096.000000          55000.000000         999479.419319
#
#        cnt_ma_rech90   fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# count   209593.00000  209593.000000      209593.000000         209593.000000
# mean         6.31543       7.716780       12396.218352           1864.595821
# std          7.19347      12.590251       16857.793882           2081.680664
# min          0.00000       0.000000           0.000000              0.000000
# 25%          2.00000       0.000000        2317.000000            773.000000
# 50%          4.00000       2.000000        7226.000000           1539.000000
# 75%          8.00000       8.000000       16000.000000           1924.000000
# max        336.00000      88.000000      953036.000000          55000.000000
#
#        medianmarechprebal90  cnt_da_rech30   fr_da_rech30  cnt_da_rech90  \
# count         209593.000000  209593.000000  209593.000000  209593.000000
# mean              92.025541     262.578110    3749.494447       0.041495
# std              369.215658    4183.897978   53885.414979       0.397556
# min             -200.000000       0.000000       0.000000       0.000000
# 25%               14.600000       0.000000       0.000000       0.000000
# 50%               36.000000       0.000000       0.000000       0.000000
# 75%               79.310000       0.000000       0.000000       0.000000
# max            41456.500000   99914.441420  999809.240107      38.000000
#
#         fr_da_rech90    cnt_loans30   amnt_loans30  maxamnt_loans30  \
# count  209593.000000  209593.000000  209593.000000    209593.000000
# mean        0.045712       2.758981      17.952021       274.658747
# std         0.951386       2.554502      17.379741      4245.264648
# min         0.000000       0.000000       0.000000         0.000000
# 25%         0.000000       1.000000       6.000000         6.000000
# 50%         0.000000       2.000000      12.000000         6.000000
# 75%         0.000000       4.000000      24.000000         6.000000
# max        64.000000      50.000000     306.000000     99864.560864
#
#        medianamnt_loans30    cnt_loans90   amnt_loans90  maxamnt_loans90  \
# count       209593.000000  209593.000000  209593.000000    209593.000000
# mean             0.054029      18.520919      23.645398         6.703134
# std              0.218039     224.797423      26.469861         2.103864
# min              0.000000       0.000000       0.000000         0.000000
# 25%              0.000000       1.000000       6.000000         6.000000
# 50%              0.000000       2.000000      12.000000         6.000000
# 75%              0.000000       5.000000      30.000000         6.000000
# max              3.000000    4997.517944     438.000000        12.000000
#
#        medianamnt_loans90      payback30      payback90
# count       209593.000000  209593.000000  209593.000000
# mean             0.046077       3.398826       4.321485
# std              0.200692       8.813729      10.308108
# min              0.000000       0.000000       0.000000
# 25%              0.000000       0.000000       0.000000
# 50%              0.000000       0.000000       1.666667
# 75%              0.000000       3.750000       4.500000
# max              3.000000     171.500000     171.500000

# %% [markdown]
# # observation

# %% [markdown]
# we can see 50% and mean data months_as_customer,age data are skewed

# %%
df.nunique()
# Out:
# Unnamed: 0              209593
# label                        2
# msisdn                  186243
# aon                       4507
# daily_decr30            147025
# daily_decr90            158669
# rental30                132148
# rental90                141033
# last_rech_date_ma         1186
# last_rech_date_da         1174
# last_rech_amt_ma            70
# cnt_ma_rech30               71
# fr_ma_rech30              1083
# sumamnt_ma_rech30        15141
# medianamnt_ma_rech30       510
# medianmarechprebal30     30428
# cnt_ma_rech90              110
# fr_ma_rech90                89
# sumamnt_ma_rech90        31771
# medianamnt_ma_rech90       608
# medianmarechprebal90     29785
# cnt_da_rech30             1066
# fr_da_rech30              1072
# cnt_da_rech90               27
# fr_da_rech90                46
# cnt_loans30                 40
# amnt_loans30                48
# maxamnt_loans30           1050
# medianamnt_loans30           6
# cnt_loans90               1110
# amnt_loans90                69
# maxamnt_loans90              3
# medianamnt_loans90           6
# payback30                 1363
# payback90                 2381
# pcircle                      1
# pdate                       82
# dtype: int64

# %% [markdown]
# # observaton

# %% [markdown]
# we have categorical values

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %% [markdown]
# # Observation

# %% [markdown]
# dropping unnamed column as it has no significance to dataset

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %% [markdown]
# # null value check

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# pdate                   0
# dtype: int64

# %% [markdown]
# # observation

# %% [markdown]
# No null values are detected

# %% [markdown]
# # univariate analysis

# %%
sns.histplot(df [ 'daily_decr30'],binwidth=50,binrange=(10,2000))
# Out:
# <AxesSubplot:xlabel='daily_decr30', ylabel='Count'>

# %% [markdown]
# # Observation

# %% [markdown]
# Daily amount spent from main account, averaged over last 30 days are below 100 indonesian rupiah on majority

# %%
sns.histplot(df ['aon'],binwidth=100,binrange=(10,2500))
# Out:
# <AxesSubplot:xlabel='aon', ylabel='Count'>

# %% [markdown]
# # observation

# %% [markdown]
# age of cellular netowork below 500 days are higher in number

# %%
sns.histplot(df ['daily_decr90'],binwidth=100,binrange=(10,1000))
# Out:
# <AxesSubplot:xlabel='daily_decr90', ylabel='Count'>

# %% [markdown]
# # observation

# %% [markdown]
# Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah) are below 200 on majority

# %%
sns.histplot(df ['rental30'],binwidth=100,binrange=(10,10000))
# Out:
# <AxesSubplot:xlabel='rental30', ylabel='Count'>

# %% [markdown]
# # observation

# %% [markdown]
# Average main account balance over last 30 days are majory below 2000 indonesian rupiah

# %%
sns.histplot(df ['cnt_loans30'],binwidth=2,binrange=(10,35))
# Out:
# <AxesSubplot:xlabel='cnt_loans30', ylabel='Count'>

# %% [markdown]
# # observation

# %% [markdown]
# Number of loans taken by user in last 30 days majority lies between 10 and 15

# %%
sns.histplot(df ['amnt_loans30'],binwidth=2,binrange=(10,100))
# Out:
# <AxesSubplot:xlabel='amnt_loans30', ylabel='Count'>

# %% [markdown]
# # observation

# %% [markdown]
# Total amount of loans taken by user in last 30 days are majorly below 20 indonesian rupiah

# %%
sns.histplot(df ['maxamnt_loans90'],binwidth=0.5,binrange=(1,15))
# Out:
# <AxesSubplot:xlabel='maxamnt_loans90', ylabel='Count'>

# %% [markdown]
# # observation

# %% [markdown]
# maximum amount of loan taken by the user are  majorly below 7 rupiah

# %%
plt.figure(figsize=(30,10))
sns.countplot(df['pcircle'])
# Out:
# <AxesSubplot:xlabel='pcircle', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# telecom circle is upw

# %%
plt.figure(figsize=(20,10))
sns.histplot(df['payback30'],binrange=(0,25),bins=3)
# Out:
# <AxesSubplot:xlabel='payback30', ylabel='Count'>

# %% [markdown]
# # Observation

# %% [markdown]
# Average payback time in days for past 30 days is mostly within 5 days

# %%
plt.figure(figsize=(20,10))
sns.histplot(df['payback90'],binrange=(0,25),bins=3)
# Out:
# <AxesSubplot:xlabel='payback90', ylabel='Count'>

# %% [markdown]
# # observation

# %% [markdown]
# Average payback time in days over last 90 day are mostly within 5 days

# %%
plt.figure(figsize=(20,10))
sns.countplot(df['maxamnt_loans90'])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans90', ylabel='count'>

# %% [markdown]
# # observation

# %% [markdown]
# maximum amount of loan taken by the user in last 90 days mostly are 6

# %%
plt.figure(figsize=(30,20))
sns.countplot(df['amnt_loans90'])
# Out:
# <AxesSubplot:xlabel='amnt_loans90', ylabel='count'>

# %% [markdown]
# # Observation

# %% [markdown]
# Total amount of loans taken by user in last 90 days are mostly 6 and 12

# %%
plt.figure(figsize=(20,10))
sns.histplot(df['rental90'],bins=200,binrange=(0,3000))
# Out:
# <AxesSubplot:xlabel='rental90', ylabel='Count'>

# %% [markdown]
# # observation

# %% [markdown]
# Average main account balance over last 90 days are majorly below 500

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(df[ 'daily_decr30'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='daily_decr30', ylabel='label'>

# %% [markdown]
# # Observation

# %% [markdown]
# Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah) increases for people who pay back loan in time

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(df[ 'rental30'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='rental30', ylabel='label'>

# %% [markdown]
# # Observation

# %% [markdown]
# Average main account balance over last 30 days more than 50000  have moslty paid the loan on time

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(df[ 'last_rech_date_ma'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='last_rech_date_ma', ylabel='label'>

# %% [markdown]
# # observation

# %% [markdown]
# Number of days till last recharge of main account are similar for both cases

# %%
sns.scatterplot(df[ 'last_rech_amt_ma'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='last_rech_amt_ma', ylabel='label'>

# %% [markdown]
# # observations

# %% [markdown]
# for people paid loan on time have recharged higher amount on last recharge

# %%
sns.scatterplot(df[ 'cnt_ma_rech30'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30', ylabel='label'>

# %% [markdown]
# # Observation

# %% [markdown]
# People paid loan on time have recharged their account many number of times in last 30 days

# %%
sns.scatterplot(df[ 'sumamnt_ma_rech30'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech30', ylabel='label'>

# %% [markdown]
# # Observation

# %% [markdown]
# People paid loan on time have higher Total amount of recharge in main account

# %%
sns.scatterplot(df[ 'medianamnt_ma_rech30'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech30', ylabel='label'>

# %% [markdown]
# # observation

# %% [markdown]
# People paid loan on time have higher Median amount of recharge done in last 30 days

# %%
sns.scatterplot(df[ 'cnt_da_rech30'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='cnt_da_rech30', ylabel='label'>

# %% [markdown]
# # observation

# %% [markdown]
# People paid loan on time have higher number of data account recharge for past 30 days

# %%
sns.scatterplot(df[ 'fr_da_rech90'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='fr_da_rech90', ylabel='label'>

# %% [markdown]
# # Observation

# %% [markdown]
# People paid loan on time have higher  Frequecy of data account got recharged in 90 days

# %%
sns.scatterplot(df[ 'cnt_loans30'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='cnt_loans30', ylabel='label'>

# %% [markdown]
# # Observation

# %% [markdown]
# People paid loan on time have higher  Number of loans taken in last 30 days

# %%
sns.scatterplot(df[ 'amnt_loans30'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='amnt_loans30', ylabel='label'>

# %% [markdown]
# # Observation

# %% [markdown]
# People paid loan on time have higher Total amount of loans taken in last 30 days

# %%
sns.scatterplot(df[ 'payback30'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='payback30', ylabel='label'>

# %% [markdown]
# # Observation

# %% [markdown]
# Average payback time in days over last 30 days

# %%
sns.scatterplot(df[ 'amnt_loans90'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='amnt_loans90', ylabel='label'>

# %% [markdown]
# # Observation

# %% [markdown]
# People Pay loan on time have higher Total amount of loans taken in last 90 days

# %%
sns.barplot(df[ 'maxamnt_loans90'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans90', ylabel='label'>

# %%
sns.scatterplot(df['fr_ma_rech90'],df[ 'label'])
# Out:
# <AxesSubplot:xlabel='fr_ma_rech90', ylabel='label'>

# %%
df.dtypes
# Out:
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# maxamnt_loans90           int64
# medianamnt_loans90      float64
# payback30               float64
# payback90               float64
# pcircle                  object
# pdate                    object
# dtype: object

# %%
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0          21.0             3078.0                1539.0
# 1           0.0             5787.0                5787.0
# 2           0.0             1539.0                1539.0
# 3           0.0                0.0                   0.0
# 4           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90 pcircle       pdate
# 0                 0.0  29.000000  29.000000     UPW  2016-07-20
# 1                 0.0   0.000000   0.000000     UPW  2016-08-10
# 2                 0.0   0.000000   0.000000     UPW  2016-08-19
# 3                 0.0   0.000000   0.000000     UPW  2016-06-06
# 4                 0.0   2.333333   2.333333     UPW  2016-06-22

# %% [markdown]
# # Encoding

# %%
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0          21.0             3078.0                1539.0
# 1           0.0             5787.0                5787.0
# 2           0.0             1539.0                1539.0
# 3           0.0                0.0                   0.0
# 4           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90 pcircle       pdate
# 0                 0.0  29.000000  29.000000     UPW  2016-07-20
# 1                 0.0   0.000000   0.000000     UPW  2016-08-10
# 2                 0.0   0.000000   0.000000     UPW  2016-08-19
# 3                 0.0   0.000000   0.000000     UPW  2016-06-06
# 4                 0.0   2.333333   2.333333     UPW  2016-06-22

# %%
df.dtypes
# Out:
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# maxamnt_loans90           int64
# medianamnt_loans90      float64
# payback30               float64
# payback90               float64
# pcircle                  object
# pdate                    object
# dtype: object

# %%
df.drop(['msisdn'],axis=1,inplace=True)

# %%
from category_encoders import OneHotEncoder

# %%
oe = OneHotEncoder(use_cat_names=True)
df['pcircle'] = oe.fit_transform(df['pcircle'])

# %%
df['day'] = pd.to_datetime(df['pdate']).dt.day
df['month'] = pd.to_datetime(df['pdate']).dt.month
df['year'] = pd.to_datetime(df['pdate']).dt.year
df.drop(['pdate'],inplace=True,axis=1)

# %%
df.dtypes
# Out:
# label                     int64
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# maxamnt_loans90           int64
# medianamnt_loans90      float64
# payback30               float64
# payback90               float64
# pcircle                   int64
# day                       int64
# month                     int64
# year                      int64
# dtype: object

# %% [markdown]
# # Observation

# %% [markdown]
# we have succesfully converted all object data to numeric data.

# %% [markdown]
# # Correlation

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,cmap="YlOrBr")
# Out:
# <AxesSubplot:>

# %%
df.corr()['label'].sort_values(ascending=False)
# Out:
# label                   1.000000
# cnt_ma_rech30           0.237331
# cnt_ma_rech90           0.236392
# sumamnt_ma_rech90       0.205793
# sumamnt_ma_rech30       0.202828
# amnt_loans90            0.199788
# amnt_loans30            0.197272
# cnt_loans30             0.196283
# daily_decr30            0.168298
# daily_decr90            0.166150
# medianamnt_ma_rech30    0.141490
# last_rech_amt_ma        0.131804
# medianamnt_ma_rech90    0.120855
# fr_ma_rech90            0.084385
# maxamnt_loans90         0.084144
# rental90                0.075521
# rental30                0.058085
# payback90               0.049183
# payback30               0.048336
# medianamnt_loans30      0.044589
# medianmarechprebal90    0.039300
# medianamnt_loans90      0.035747
# cnt_loans90             0.004733
# cnt_da_rech30           0.003827
# last_rech_date_ma       0.003728
# cnt_da_rech90           0.002999
# last_rech_date_da       0.001711
# fr_ma_rech30            0.001330
# Unnamed: 0              0.000403
# maxamnt_loans30         0.000248
# fr_da_rech30           -0.000027
# aon                    -0.003785
# medianmarechprebal30   -0.004829
# fr_da_rech90           -0.005418
# Name: label, dtype: float64

# %% [markdown]
# # observation

# %% [markdown]
# cnt_ma_rech30,cnt_ma_rech90,sumamnt_ma_rech90,sumamnt_ma_rech30,amnt_loans90,amnt_loans30 are positively correlated with people paying loan on time

# %% [markdown]
# fr_da_rech30,aon,medianmarechprebal30,fr_da_rech90 are negatively correlated with people paying loan on time

# %% [markdown]
# # Skewness

# %%
df.head()
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  241.0     21.228000     21.228000    159.42    159.42
# 4      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 0          21.0             3078.0                1539.0
# 1           0.0             5787.0                5787.0
# 2           0.0             1539.0                1539.0
# 3           0.0                0.0                   0.0
# 4           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 0                  7.50              2            21               3078
# 1                 61.04              1             0               5787
# 2                 66.32              1             0               1539
# 3                  0.00              1             0                947
# 4                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 0                1539.0                  7.50            0.0           0.0
# 1                5787.0                 61.04            0.0           0.0
# 2                1539.0                 66.32            0.0           0.0
# 3                 947.0                  2.50            0.0           0.0
# 4                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 0              0             0            2            12              6.0
# 1              0             0            1            12             12.0
# 2              0             0            1             6              6.0
# 3              0             0            2            12              6.0
# 4              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 0                 0.0          2.0            12                6
# 1                 0.0          1.0            12               12
# 2                 0.0          1.0             6                6
# 3                 0.0          2.0            12                6
# 4                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90  pcircle  day  month  year
# 0                 0.0  29.000000  29.000000        1   20      7  2016
# 1                 0.0   0.000000   0.000000        1   10      8  2016
# 2                 0.0   0.000000   0.000000        1   19      8  2016
# 3                 0.0   0.000000   0.000000        1    6      6  2016
# 4                 0.0   2.333333   2.333333        1   22      6  2016

# %%
dc1 = df.drop(['label',"day","month","year",'pcircle'],axis=1)

# %%
dc1.shape
# Out:
# (209593, 32)

# %%
dc1.plot(kind='hist',subplots=True,layout=(6,6),figsize=(20,10))
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %%
dc1.skew().sort_values(ascending=False)
# Out:
# medianmarechprebal90    44.880503
# fr_da_rech90            28.988083
# cnt_da_rech90           27.267278
# cnt_da_rech30           17.818364
# maxamnt_loans30         17.658052
# cnt_loans90             16.594408
# last_rech_date_da       14.814857
# last_rech_date_ma       14.790974
# medianmarechprebal30    14.779875
# fr_da_rech30            14.776430
# fr_ma_rech30            14.772833
# aon                     10.392949
# payback30                8.310695
# payback90                6.899951
# sumamnt_ma_rech30        6.386787
# sumamnt_ma_rech90        4.897950
# medianamnt_loans90       4.895720
# medianamnt_loans30       4.551043
# rental30                 4.521929
# rental90                 4.437681
# daily_decr90             4.252565
# daily_decr30             3.946230
# last_rech_amt_ma         3.781149
# medianamnt_ma_rech90     3.752706
# medianamnt_ma_rech30     3.512324
# cnt_ma_rech90            3.425254
# cnt_ma_rech30            3.283842
# amnt_loans90             3.150006
# amnt_loans30             2.975719
# cnt_loans30              2.713421
# fr_ma_rech90             2.285423
# maxamnt_loans90          1.678304
# dtype: float64

# %% [markdown]
# # observation

# %% [markdown]
# Many features have skewness

# %%
from sklearn.preprocessing import power_transform
dc2 = power_transform(dc1)

# %%
dc2 = pd.DataFrame(dc2,columns=dc1.columns)

# %%
dc2.skew()
# Out:
# aon                       1.654517
# daily_decr30             -6.582717
# daily_decr90             -7.080193
# rental30                 -1.022844
# rental90                 -0.962717
# last_rech_date_ma        -5.362529
# last_rech_date_da      -106.606655
# last_rech_amt_ma         -0.061262
# cnt_ma_rech30            -0.000145
# fr_ma_rech30              0.165015
# sumamnt_ma_rech30        -0.291322
# medianamnt_ma_rech30     -0.189628
# medianmarechprebal30     -0.119058
# cnt_ma_rech90            -0.002465
# fr_ma_rech90              0.142952
# sumamnt_ma_rech90        -0.192158
# medianamnt_ma_rech90     -0.044604
# medianmarechprebal90      7.506286
# cnt_da_rech30             6.925820
# fr_da_rech30             11.390665
# cnt_da_rech90             6.006577
# fr_da_rech90             15.469700
# cnt_loans30               0.036243
# amnt_loans30              0.001948
# maxamnt_loans30          -1.680107
# medianamnt_loans30        3.447735
# cnt_loans90               0.105580
# amnt_loans90             -0.008988
# maxamnt_loans90           0.364282
# medianamnt_loans90        3.779598
# payback30                 0.298563
# payback90                 0.210887
# dtype: float64

# %% [markdown]
# # observation

# %% [markdown]
# we have removed skewness

# %% [markdown]
# # outlier removal

# %%
dc2.plot(kind="box",subplots=True,layout=(6,6),figsize=(20,20))
# Out:
# aon                        AxesSubplot(0.125,0.772143;0.110714x0.107857)
# daily_decr30            AxesSubplot(0.257857,0.772143;0.110714x0.107857)
# daily_decr90            AxesSubplot(0.390714,0.772143;0.110714x0.107857)
# rental30                AxesSubplot(0.523571,0.772143;0.110714x0.107857)
# rental90                AxesSubplot(0.656429,0.772143;0.110714x0.107857)
# last_rech_date_ma       AxesSubplot(0.789286,0.772143;0.110714x0.107857)
# last_rech_date_da          AxesSubplot(0.125,0.642714;0.110714x0.107857)
# last_rech_amt_ma        AxesSubplot(0.257857,0.642714;0.110714x0.107857)
# cnt_ma_rech30           AxesSubplot(0.390714,0.642714;0.110714x0.107857)
# fr_ma_rech30            AxesSubplot(0.523571,0.642714;0.110714x0.107857)
# sumamnt_ma_rech30       AxesSubplot(0.656429,0.642714;0.110714x0.107857)
# medianamnt_ma_rech30    AxesSubplot(0.789286,0.642714;0.110714x0.107857)
# medianmarechprebal30       AxesSubplot(0.125,0.513286;0.110714x0.107857)
# cnt_ma_rech90           AxesSubplot(0.257857,0.513286;0.110714x0.107857)
# fr_ma_rech90            AxesSubplot(0.390714,0.513286;0.110714x0.107857)
# sumamnt_ma_rech90       AxesSubplot(0.523571,0.513286;0.110714x0.107857)
# medianamnt_ma_rech90    AxesSubplot(0.656429,0.513286;0.110714x0.107857)
# medianmarechprebal90    AxesSubplot(0.789286,0.513286;0.110714x0.107857)
# cnt_da_rech30              AxesSubplot(0.125,0.383857;0.110714x0.107857)
# fr_da_rech30            AxesSubplot(0.257857,0.383857;0.110714x0.107857)
# cnt_da_rech90           AxesSubplot(0.390714,0.383857;0.110714x0.107857)
# fr_da_rech90            AxesSubplot(0.523571,0.383857;0.110714x0.107857)
# cnt_loans30             AxesSubplot(0.656429,0.383857;0.110714x0.107857)
# amnt_loans30            AxesSubplot(0.789286,0.383857;0.110714x0.107857)
# maxamnt_loans30            AxesSubplot(0.125,0.254429;0.110714x0.107857)
# medianamnt_loans30      AxesSubplot(0.257857,0.254429;0.110714x0.107857)
# cnt_loans90             AxesSubplot(0.390714,0.254429;0.110714x0.107857)
# amnt_loans90            AxesSubplot(0.523571,0.254429;0.110714x0.107857)
# maxamnt_loans90         AxesSubplot(0.656429,0.254429;0.110714x0.107857)
# medianamnt_loans90      AxesSubplot(0.789286,0.254429;0.110714x0.107857)
# payback30                     AxesSubplot(0.125,0.125;0.110714x0.107857)
# payback90                  AxesSubplot(0.257857,0.125;0.110714x0.107857)
# dtype: object

# %%
dc2.shape
# Out:
# (209593, 32)

# %%
from scipy.stats import zscore

# %%
z= np.abs(zscore(dc2))

# %%
np.where(z>7)
# Out:
# (array([    30,     30,     53, ..., 209533, 209568, 209576], dtype=int64),
#  array([ 0,  5,  5, ...,  5, 18,  0], dtype=int64))

# %%
df1 = dc2[(z<7).all(axis=1)]

# %%
df1.shape
# Out:
# (195963, 32)

# %% [markdown]
# # observation

# %% [markdown]
# the outliers are removed

# %% [markdown]
# # data loss

# %%
((209593-195963)/209593)*100
# Out:
# 6.503079778427715

# %% [markdown]
# # observation

# %% [markdown]
# 6.5% Data loss

# %% [markdown]
# # creating categorical data dataframe

# %%
dfd = pd.DataFrame()
dfd['label'] = df['label']
dfd["Day"] = df["day"]
dfd["Month"] = df["month"]
dfd["Year"] = df["year"]
dfd['pcircle'] = df['pcircle']
dfd.shape
# Out:
# (209593, 5)

# %% [markdown]
# # removing the outlier removed rows in categorical dataframe

# %%
dfd.drop(np.where(z>7)[0],axis=0,inplace=True)

# %%
dfd.shape
# Out:
# (195963, 5)

# %%
dx = df1.join(dfd)
dx.drop(['label'],axis=1,inplace=True)
dx.shape
# Out:
# (195963, 36)

# %%
dy = dfd.iloc[:,0]

# %% [markdown]
# # Data Balancing

# %%
sns.countplot(dfd.iloc[:,0])
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %% [markdown]
# # Observations

# %% [markdown]
# The Data is imbalanced so we need to balance it

# %%
from imblearn.over_sampling import SMOTE 
sm = SMOTE()
x,y=sm.fit_resample(dx,dy)

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
x.shape
# Out:
# (343066, 36)

# %% [markdown]
# # Observations

# %% [markdown]
#  data is now balanced

# %% [markdown]
# # Standard Scaler

# %%
sc1=x.iloc[:,:-4]
sc1.shape
# Out:
# (343066, 32)

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x1=sc.fit_transform(sc1)
sc_final = pd.DataFrame(x1,columns=sc1.columns)

# %% [markdown]
# # Observation

# %% [markdown]
# Now we have scaled the data

# %% [markdown]
# # PCA

# %%
sc_final.shape
# Out:
# (343066, 32)

# %%
x_input = sc_final.join(x.iloc[:,-4:])
x_input.shape
# Out:
# (343066, 36)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA().fit(x_input)
fig, ax = plt.subplots(figsize=(40,10))
xi = np.arange(1, 37, step=1)
yi = np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(xi, yi, marker='o', linestyle='--', color='b')

plt.xlabel('Number of Components')
plt.xticks(np.arange(0, 1227, step=1)) #change from 0-based array index to 1-based human-readable label
plt.ylabel('Cumulative variance (%)')
plt.title('The number of components needed to explain variance')

plt.axhline(y=1, color='r', linestyle='-')
plt.text(0.5, 0.85, '100% cut-off threshold', color = 'red', fontsize=16)

ax.grid(axis='x')
plt.figure(figsize=(100,20))
plt.show()

# %%
pd.DataFrame(yi)
# Out:
#            0
# 0   0.692522
# 1   0.806155
# 2   0.836712
# 3   0.859609
# 4   0.879809
# 5   0.899749
# 6   0.916109
# 7   0.930360
# 8   0.941107
# 9   0.951779
# 10  0.961164
# 11  0.970196
# 12  0.976568
# 13  0.981191
# 14  0.985144
# 15  0.988384
# 16  0.991331
# 17  0.993265
# 18  0.994818
# 19  0.995774
# 20  0.996621
# 21  0.997406
# 22  0.998171
# 23  0.998734
# 24  0.999134
# 25  0.999425
# 26  0.999691
# 27  0.999908
# 28  0.999961
# 29  0.999986
# 30  1.000000
# 31  1.000000
# 32  1.000000
# 33  1.000000
# 34  1.000000
# 35  1.000000

# %% [markdown]
# # we can see for 29 columns i wont loose any data so i set threshold to 29 for PCA

# %%
pca = PCA(n_components=29)
p_final=pca.fit_transform(x_input)

# %%
x_final = pd.DataFrame(p_final)
x_final.shape
# Out:
# (343066, 29)

# %% [markdown]
# # Multicolinearity Checking

# %% [markdown]
# # variance inflation factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif["vif value"] = [variance_inflation_factor(x_final.values,a) for a in range(29)]
vif["feature names"] = x_final.columns

# %%
vif.sort_values(by=["vif value"],ascending=False)
# Out:
#     vif value  feature names
# 12        1.0             12
# 28        1.0             28
# 11        1.0             11
# 20        1.0             20
# 18        1.0             18
# 15        1.0             15
# 13        1.0             13
# 26        1.0             26
# 25        1.0             25
# 24        1.0             24
# 0         1.0              0
# 10        1.0             10
# 6         1.0              6
# 2         1.0              2
# 3         1.0              3
# 4         1.0              4
# 14        1.0             14
# 7         1.0              7
# 8         1.0              8
# 17        1.0             17
# 16        1.0             16
# 19        1.0             19
# 9         1.0              9
# 21        1.0             21
# 22        1.0             22
# 1         1.0              1
# 27        1.0             27
# 5         1.0              5
# 23        1.0             23

# %% [markdown]
# # Observation

# %% [markdown]
# No Mulitcolinearity as PCA TAKES care of mulitcolinearity

# %% [markdown]
# # model Training starts

# %% [markdown]
# # Importing required libraries

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # i have write a code block that tests data with models and rank them according to cross val score and accuracy score

# %%
algo = [DecisionTreeClassifier(),KNeighborsClassifier(),RandomForestClassifier(),AdaBoostClassifier(),LogisticRegression()]
result = pd.DataFrame(columns=["Algorithm Name","Accuracy Score","Cross Validation Score"])

dtc=[]
knc=[]
rfc=[]
abc=[]
lr=[]
fl = [dtc,knc,rfc,abc,lr]

oo=0

for i in algo:
    rand=0
    acc=0    
    
    for ii in range(2):
        train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.20,random_state=ii)
        cf = i
        cf.fit(train_x,train_y)
        pred = cf.predict(test_x)
        ac = accuracy_score(test_y,pred)
        if ac>acc:
            acc=ac
            rand=ii
    print(f' the best random state is {rand} for algorithm {i}')
    
    
    train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.20,random_state=rand)
    cf = i
    cf.fit(train_x,train_y)
    pred = cf.predict(test_x)
    ac = accuracy_score(test_y,pred)
    cv = cross_val_score(cf,x_final,y,cv=5).mean()
    fl[oo].insert(0,i)
    fl[oo].insert(1,ac)
    fl[oo].insert(2,cv)
    result.loc[oo] = fl[oo]
    oo +=1
    
    
final_result = result.sort_values(by=["Accuracy Score","Cross Validation Score"],ascending=False)
# Out:
#  the best random state is 1 for algorithm DecisionTreeClassifier()
#  the best random state is 1 for algorithm KNeighborsClassifier()
#  the best random state is 1 for algorithm RandomForestClassifier()
#  the best random state is 1 for algorithm AdaBoostClassifier()
#  the best random state is 0 for algorithm LogisticRegression()

# %%
final_result
# Out:
#                                       Algorithm Name  Accuracy Score  \
# 2  (DecisionTreeClassifier(max_features='auto', r...        0.936179
# 1                             KNeighborsClassifier()        0.891801
# 0                           DecisionTreeClassifier()        0.878829
# 3  (DecisionTreeClassifier(max_depth=1, random_st...        0.802140
# 4                               LogisticRegression()        0.777276
#
#    Cross Validation Score
# 2                0.937117
# 1                0.891808
# 0                0.879705
# 3                0.800942
# 4                0.777445

# %%
final_result.loc[2]["Algorithm Name"]
# Out:
# RandomForestClassifier()

# %% [markdown]
# # running Support vector classifier induvidually as it consumes more memory

# %%
svc = SVC()
train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.20,random_state=10)
svc.fit(train_x,train_y)
pred = svc.predict(test_x)
ac = accuracy_score(test_y,pred)
cv = cross_val_score(svc,x_final,y,cv=5).mean()
print(f' the accuracy socre is {ac}, the cross validation score is {cv} for SVC' )

# %% [markdown]
# # Observation

# %% [markdown]
# from all the classifier models Logistic Regression performed best with accuracy of 90 % and cross val score of 85 %

# %% [markdown]
# # HyperParameter Tunining

# %%
from sklearn.model_selection import GridSearchCV

# %%
rf = RandomForestClassifier()
parameters = {'bootstrap': [True, False],
 'max_depth': [10, None],
 'max_features': ['auto', 'sqrt'],
 'min_samples_leaf': [1, 2],}
train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.20,random_state=1)
gsv = GridSearchCV(rf,parameters)
gsv.fit(train_x,train_y)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False], 'max_depth': [10, None],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2]})

# %%
gsv.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': None,
#  'max_features': 'auto',
#  'min_samples_leaf': 1}

# %% [markdown]
# # using the best parameters got in grid search

# %%
rf = RandomForestClassifier(bootstrap=False,max_depth=None,max_features='auto',min_samples_leaf=1)
train_x,test_x,train_y,test_y = train_test_split(x_final,y,test_size=.20,random_state=1)
rf.fit(train_x,train_y)
pred = rf.predict(test_x)
ac = accuracy_score(test_y,pred)
cv = cross_val_score(rf,x_final,y,cv=5).mean()
print(f' the accuracy socre is {ac}, the cross validation score is {cv} ' )
# Out:
#  the accuracy socre is 0.9451861136211269, the cross validation score is 0.945430330745071

# %% [markdown]
# # Observation

# %% [markdown]
# the accuracy score is 94% and cross validation score is 94%

# %%
print(classification_report(test_y,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.95     34299
#            1       0.95      0.94      0.94     34315
#
#     accuracy                           0.95     68614
#    macro avg       0.95      0.95      0.95     68614
# weighted avg       0.95      0.95      0.95     68614

# %%
print(confusion_matrix(test_y,pred))
# Out:
# [[32744  1555]
#  [ 2206 32109]]

# %% [markdown]
# # ROC_AUC_CURVE

# %%
from sklearn.metrics import plot_roc_curve,roc_auc_score

# %%
print(f'The Roc Auc Score is {roc_auc_score(test_y,pred)}')
# Out:
# The Roc Auc Score is 0.9451883231009798

# %%
plot_roc_curve(rf,test_x,test_y)

# %% [markdown]
# # saving the model

# %%
import joblib
joblib.dump(rf,"Micro-credit.pkl")
# Out:
# ['Micro-credit.pkl']
